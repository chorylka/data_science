# %%
import pandas as pd
data = pd.read_csv ("https://raw.githubusercontent.com/gorkang/2020-corona/master/outputs/raw_data.csv")
#data.sample(100)
data.sample(100).sort_values('deaths_sum', ascending = False)
# Out:
#               country        time  cases_sum  cases_diff  deaths_sum  \
# 15451  United Kingdom  2020-03-29      19780        2468      1231.0
# 9600           Mexico  2020-04-21       8772         511       712.0
# 7807    Korea (South)  2020-04-05      10237          81       183.0
# 3989   Czech Republic  2020-04-12       5991         160       138.0
# 10458     Netherlands  2020-03-20       3003         536       107.0
# ...               ...         ...        ...         ...         ...
# 1777           Bhutan  2020-04-19          5           0         0.0
# 9538           Mexico  2020-02-18          0           0         0.0
# 13143    Sierra Leone  2020-04-07          6           0         0.0
# 16119          Zambia  2020-02-15          0           0         0.0
# 7024          Ireland  2020-01-24          0           0         0.0
#
#        deaths_diff        source
# 15451        210.0           JHU
# 9600          26.0  worldometers
# 7807           6.0           JHU
# ...

# %%
#estes são alguns de testes com os data sets do Corona do Gorka Navarrete da Adolfo Ibañez University
data.cases_sum.sample(20)
# Out:
# 16207       0
# 11878     439
# 13940      10
# 9380        0
# 14832      70
# 6838     5136
# 10759       0
# 13415    1205
# 1544        0
# 6878       95
# 9809        0
# 11286    4016
# 9678     1438
# 3243        0
# 14831      65
# 6521        0
# 12446      15
# 46          4
# 11871      18
# 4770        1
# Name: cases_sum, dtype: int64

# %%
dados_finais = data.cases_sum
dados_finais.describe()
# Out:
# count    1.627400e+04
# mean     3.136983e+03
# std      3.184662e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.100000e+02
# max      2.499546e+06
# Name: cases_sum, dtype: float64

# %%
data
# Out:
#            country        time  cases_sum  cases_diff  deaths_sum  \
# 0      Afghanistan  2020-01-23          0           0         0.0
# 1      Afghanistan  2020-01-24          0           0         0.0
# 2      Afghanistan  2020-01-25          0           0         0.0
# 3      Afghanistan  2020-01-26          0           0         0.0
# 4      Afghanistan  2020-01-27          0           0         0.0
# ...            ...         ...        ...         ...         ...
# 16269     Zimbabwe  2020-04-17         24           1         3.0
# 16270     Zimbabwe  2020-04-18         25           1         3.0
# 16271     Zimbabwe  2020-04-19         25           0         3.0
# 16272     Zimbabwe  2020-04-20         25           0         3.0
# 16273     Zimbabwe  2020-04-21         25           0         3.0
#
#        deaths_diff        source
# 0              0.0           JHU
# 1              0.0           JHU
# 2              0.0           JHU
# 3              0.0           JHU
# ...

# %%
new_cases_sum = data.groupby("country")["cases_sum"]
new_cases_sum.head()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16185    0
# 16186    0
# 16187    0
# 16188    0
# 16189    0
# Name: cases_sum, Length: 920, dtype: int64

# %%
data
# Out:
#            country        time  cases_sum  cases_diff  deaths_sum  \
# 0      Afghanistan  2020-01-23          0           0         0.0
# 1      Afghanistan  2020-01-24          0           0         0.0
# 2      Afghanistan  2020-01-25          0           0         0.0
# 3      Afghanistan  2020-01-26          0           0         0.0
# 4      Afghanistan  2020-01-27          0           0         0.0
# ...            ...         ...        ...         ...         ...
# 16269     Zimbabwe  2020-04-17         24           1         3.0
# 16270     Zimbabwe  2020-04-18         25           1         3.0
# 16271     Zimbabwe  2020-04-19         25           0         3.0
# 16272     Zimbabwe  2020-04-20         25           0         3.0
# 16273     Zimbabwe  2020-04-21         25           0         3.0
#
#        deaths_diff        source
# 0              0.0           JHU
# 1              0.0           JHU
# 2              0.0           JHU
# 3              0.0           JHU
# ...

# %%
data2= data.country
data2.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
data.head()
# Out:
#        country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 0  Afghanistan  2020-01-23          0           0         0.0          0.0
# 1  Afghanistan  2020-01-24          0           0         0.0          0.0
# 2  Afghanistan  2020-01-25          0           0         0.0          0.0
# 3  Afghanistan  2020-01-26          0           0         0.0          0.0
# 4  Afghanistan  2020-01-27          0           0         0.0          0.0
#
#   source
# 0    JHU
# 1    JHU
# 2    JHU
# 3    JHU
# 4    JHU

# %%
cases_total= data.cases_sum.sample(100)

# %%
cases_total.sample(100)
# Out:
# 3291         0
# 3428         2
# 8476         0
# 5356         0
# 9429         0
#          ...
# 886      14671
# 12723        0
# 9218         4
# 5154      4014
# 15993        4
# Name: cases_sum, Length: 100, dtype: int64

# %%
country_com_total = pd.concat([data2,cases_total])
country_com_total.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# dtype: object

# %%
data2
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 16269       Zimbabwe
# 16270       Zimbabwe
# 16271       Zimbabwe
# 16272       Zimbabwe
# 16273       Zimbabwe
# Name: country, Length: 16274, dtype: object

# %%
cases_total
# Out:
# 15588       8
# 5356        0
# 3948        3
# 14966       0
# 6434        0
#          ...
# 9218        4
# 6317        0
# 6500        0
# 11625    2084
# 11502       0
# Name: cases_sum, Length: 100, dtype: int64

# %%
total_cases = data.join(cases_total, on="country")
total_cases.sort_values('nota', ascending=False)
#classifica por nota nota == NaN é filme sem nota
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-7042ce7cfcb7> in <module>
# ----> 1 total_cases = data.join(cases_total, on="country")
#       2 total_cases.sort_values('nota', ascending=False)
#       3 #classifica por nota nota == NaN é filme sem nota
#
# /opt/anaconda3/envs/chorylka/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# /opt/anaconda3/envs/chorylka/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
# ...

# %%
data.sample(10)
# Out:
#           country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 9244         Mali  2020-04-21        246           0        14.0          0.0
# 14219      Sweden  2020-04-16      12540         613      1333.0        130.0
# 14102   Swaziland  2020-03-18          1           0         0.0          0.0
# 9431    Mauritius  2020-01-31          0           0         0.0          0.0
# 4848      Estonia  2020-03-13         79          63         0.0          0.0
# 3201     Colombia  2020-01-23          0           0         0.0          0.0
# 5168       France  2020-02-05          6           0         0.0          0.0
# 13039  Seychelles  2020-03-23          7           0         0.0          0.0
# 8637   Luxembourg  2020-02-06          0           0         0.0          0.0
# 13723       Spain  2020-02-23          2           0         0.0          0.0
#
#              source
# 9244   worldometers
# 14219           JHU
# 14102           JHU
# 9431            JHU
# ...

# %%
data.sort_values('cases_sum', ascending=False)
# Out:
#            country        time  cases_sum  cases_diff  deaths_sum  \
# 14852       Total:  2020-04-21    2499546     2498825    171338.0
# 14846       Total:  2020-04-21    1125266      272958    105217.0
# 15652          USA  2020-04-21     792938       22378     42518.0
# 15651          USA  2020-04-20     770560       23639     39859.0
# 15650          USA  2020-04-19     746921       26440     38671.0
# ...            ...         ...        ...         ...         ...
# 10156      Myanmar  2020-02-13          0           0         0.0
# 10155      Myanmar  2020-02-12          0           0         0.0
# 10154      Myanmar  2020-02-11          0           0         0.0
# 10153      Myanmar  2020-02-10          0           0         0.0
# 0      Afghanistan  2020-01-23          0           0         0.0
#
#        deaths_diff        source
# 14852     171323.0  worldometers
# 14846      59741.0  worldometers
# 15652       2659.0  worldometers
# 15651       1188.0           JHU
# ...

# %%
data.describe()
# Out:
#           cases_sum    cases_diff     deaths_sum    deaths_diff
# count  1.627400e+04  1.627400e+04   16247.000000   16247.000000
# mean   3.136983e+03  2.544933e+02     184.599249      18.285407
# std    3.184662e+04  2.070200e+04    2163.473468    1594.440012
# min    0.000000e+00 -7.231530e+05       0.000000  -89919.000000
# 25%    0.000000e+00  0.000000e+00       0.000000       0.000000
# 50%    1.000000e+00  0.000000e+00       0.000000       0.000000
# 75%    1.100000e+02  8.000000e+00       1.000000       0.000000
# max    2.499546e+06  2.498825e+06  171338.000000  171323.000000

# %%
data
# Out:
#            country        time  cases_sum  cases_diff  deaths_sum  \
# 0      Afghanistan  2020-01-23          0           0         0.0
# 1      Afghanistan  2020-01-24          0           0         0.0
# 2      Afghanistan  2020-01-25          0           0         0.0
# 3      Afghanistan  2020-01-26          0           0         0.0
# 4      Afghanistan  2020-01-27          0           0         0.0
# ...            ...         ...        ...         ...         ...
# 16269     Zimbabwe  2020-04-17         24           1         3.0
# 16270     Zimbabwe  2020-04-18         25           1         3.0
# 16271     Zimbabwe  2020-04-19         25           0         3.0
# 16272     Zimbabwe  2020-04-20         25           0         3.0
# 16273     Zimbabwe  2020-04-21         25           0         3.0
#
#        deaths_diff        source
# 0              0.0           JHU
# 1              0.0           JHU
# 2              0.0           JHU
# 3              0.0           JHU
# ...

# %%
data.query("country=='Brazil'")
# Out:
#      country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 2047  Brazil  2020-01-23          0           0         0.0          0.0
# 2048  Brazil  2020-01-24          0           0         0.0          0.0
# 2049  Brazil  2020-01-25          0           0         0.0          0.0
# 2050  Brazil  2020-01-26          0           0         0.0          0.0
# 2051  Brazil  2020-01-27          0           0         0.0          0.0
# ...      ...         ...        ...         ...         ...          ...
# 2131  Brazil  2020-04-17      33682        3257      2141.0        217.0
# 2132  Brazil  2020-04-18      36658        2976      2354.0        213.0
# 2133  Brazil  2020-04-19      38654        1996      2462.0        108.0
# 2134  Brazil  2020-04-20      40743        2089      2587.0        125.0
# 2135  Brazil  2020-04-21      40814          71      2588.0          1.0
#
#             source
# 2047           JHU
# 2048           JHU
# 2049           JHU
# ...

# %%
brazil_data = data.query("country=='Brazil'")
brazil_data.sample(89)
# Out:
#      country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 2077  Brazil  2020-02-22          0           0         0.0          0.0
# 2076  Brazil  2020-02-21          0           0         0.0          0.0
# 2120  Brazil  2020-04-06      12161        1031       564.0         78.0
# 2085  Brazil  2020-03-01          2           0         0.0          0.0
# 2064  Brazil  2020-02-09          0           0         0.0          0.0
# ...      ...         ...        ...         ...         ...          ...
# 2094  Brazil  2020-03-10         31           6         0.0          0.0
# 2073  Brazil  2020-02-18          0           0         0.0          0.0
# 2056  Brazil  2020-02-01          0           0         0.0          0.0
# 2122  Brazil  2020-04-08      16170        2136       819.0        133.0
# 2103  Brazil  2020-03-20        793         172        11.0          5.0
#
#      source
# 2077    JHU
# 2076    JHU
# 2120    JHU
# 2085    JHU
# 2064    JHU
# ...

# %%
brazil_data.sort_values('cases_sum', ascending=False)
# Out:
#      country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 2135  Brazil  2020-04-21      40814          71      2588.0          1.0
# 2134  Brazil  2020-04-20      40743        2089      2587.0        125.0
# 2133  Brazil  2020-04-19      38654        1996      2462.0        108.0
# 2132  Brazil  2020-04-18      36658        2976      2354.0        213.0
# 2131  Brazil  2020-04-17      33682        3257      2141.0        217.0
# ...      ...         ...        ...         ...         ...          ...
# 2077  Brazil  2020-02-22          0           0         0.0          0.0
# 2078  Brazil  2020-02-23          0           0         0.0          0.0
# 2079  Brazil  2020-02-24          0           0         0.0          0.0
# 2080  Brazil  2020-02-25          0           0         0.0          0.0
# 2047  Brazil  2020-01-23          0           0         0.0          0.0
#
#             source
# 2135  worldometers
# 2134           JHU
# 2133           JHU
# ...

# %%
brazil_data.sort_values('cases_sum', ascending=False)
# Out:
#      country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 2135  Brazil  2020-04-21      40814          71      2588.0          1.0
# 2134  Brazil  2020-04-20      40743        2089      2587.0        125.0
# 2133  Brazil  2020-04-19      38654        1996      2462.0        108.0
# 2132  Brazil  2020-04-18      36658        2976      2354.0        213.0
# 2131  Brazil  2020-04-17      33682        3257      2141.0        217.0
# ...      ...         ...        ...         ...         ...          ...
# 2077  Brazil  2020-02-22          0           0         0.0          0.0
# 2078  Brazil  2020-02-23          0           0         0.0          0.0
# 2079  Brazil  2020-02-24          0           0         0.0          0.0
# 2080  Brazil  2020-02-25          0           0         0.0          0.0
# 2047  Brazil  2020-01-23          0           0         0.0          0.0
#
#             source
# 2135  worldometers
# 2134           JHU
# 2133           JHU
# ...

# %%
brazil_data.sort_values('cases_sum', ascending=False)
# Out:
#      country        time  cases_sum  cases_diff  deaths_sum  deaths_diff  \
# 2135  Brazil  2020-04-21      40814          71      2588.0          1.0
# 2134  Brazil  2020-04-20      40743        2089      2587.0        125.0
# 2133  Brazil  2020-04-19      38654        1996      2462.0        108.0
# 2132  Brazil  2020-04-18      36658        2976      2354.0        213.0
# 2131  Brazil  2020-04-17      33682        3257      2141.0        217.0
# ...      ...         ...        ...         ...         ...          ...
# 2077  Brazil  2020-02-22          0           0         0.0          0.0
# 2078  Brazil  2020-02-23          0           0         0.0          0.0
# 2079  Brazil  2020-02-24          0           0         0.0          0.0
# 2080  Brazil  2020-02-25          0           0         0.0          0.0
# 2047  Brazil  2020-01-23          0           0         0.0          0.0
#
#             source
# 2135  worldometers
# 2134           JHU
# 2133           JHU
# ...

# %%
brazil_data.columns = ["Pais", "data", "soma_dos_casos", "cases_diff", "soma_das_mortes", "deaths_diff", "fonte"]
brazil_data_final = brazil_data[['Pais', 'soma_dos_casos', 'data']]
brazil_data_final.sort_values('soma_dos_casos', ascending=False)
#brazil_data_final.sample(10)
# Out:
#         Pais  soma_dos_casos        data
# 2135  Brazil           40814  2020-04-21
# 2134  Brazil           40743  2020-04-20
# 2133  Brazil           38654  2020-04-19
# 2132  Brazil           36658  2020-04-18
# 2131  Brazil           33682  2020-04-17
# ...      ...             ...         ...
# 2077  Brazil               0  2020-02-22
# 2078  Brazil               0  2020-02-23
# 2079  Brazil               0  2020-02-24
# 2080  Brazil               0  2020-02-25
# 2047  Brazil               0  2020-01-23
#
# [89 rows x 3 columns]

# %%
brazil_data_final.plot()
